# %%
import logging
import time
import os
import argparse
import numpy as np
import pandas as pd
import wandb
import matplotlib.pyplot as plt


from citylearn.citylearn import CityLearnEnv
from utilities.utils import set_seed

from agents.user_agent import SubmissionAgent
from rewards.user_reward import SubmissionReward

# %%
import citylearn
print(citylearn.__version__)
# Out:
# 2.1b12

# %%
class WrapperEnv:
    """
    Env to wrap provide Citylearn Env data without providing full env
    Preventing attribute access outside of the available functions
    """
    def __init__(self, env_data):
        self.observation_names = env_data['observation_names']
        self.action_names = env_data['action_names']
        self.observation_space = env_data['observation_space']
        self.action_space = env_data['action_space']
        self.time_steps = env_data['time_steps']
        self.seconds_per_time_step = env_data['seconds_per_time_step']
        self.random_seed = env_data['random_seed']
        self.buildings_metadata = env_data['buildings_metadata']
        self.episode_tracker = env_data['episode_tracker']
    
    def get_metadata(self):
        return {'buildings': self.buildings_metadata}

def create_citylearn_env(config, reward_function):
    #env = CityLearnEnv(config.SCHEMA, reward_function=reward_function,central_agent=True)
    env = CityLearnEnv(config.SCHEMA, reward_function=reward_function,central_agent=False)

    env_data = dict(
        observation_names = env.observation_names,
        action_names = env.action_names,
        observation_space = env.observation_space,
        action_space = env.action_space,
        time_steps = env.time_steps,
        random_seed = None,
        episode_tracker = None,
        seconds_per_time_step = None,
        buildings_metadata = env.get_metadata()['buildings']
    )

    wrapper_env = WrapperEnv(env_data)
    return env, wrapper_env

# %%
def update_power_outage_random_seed(env: CityLearnEnv, random_seed: int) -> CityLearnEnv:
    """Update random seed used in generating power outage signals.
    
    Used to optionally update random seed for stochastic power outage model in all buildings.
    Random seeds should be updated before calling :py:meth:`citylearn.citylearn.CityLearnEnv.reset`.
    """

    for b in env.buildings:
        b.stochastic_power_outage_model.random_seed = random_seed

    return env

# %%
def train(config, algorithm_config, episodes: int = None):
       
        """Train agent.

        Parameters
        ----------
        episodes: int, default: 1
            Number of training episode >= 1.
        logging_level: int, default: 30
            Logging level where increasing the number silences lower level information.
        """
        
        print("Starting local training")
    
        env, wrapper_env = create_citylearn_env(config, SubmissionReward)
        #print("Env Created")
        #print('Current time step:', env.time_step)
        #print('environment number of time steps:', env.time_steps)
        #print('environment uses central agent:', env.central_agent)
        #print('Common (shared) observations amogst buildings:', env.shared_observations)
        #print('Number of buildings:', len(env.buildings))

        agent = SubmissionAgent(wrapper_env, **algorithm_config)

        episodes_completed = 0

        episodes = 1 if episodes is None else episodes
        
        # Step 1: Initialize Variables for Storage
        rewards_over_episodes = []

        for episode in range(episodes):
            
            #env = update_power_outage_random_seed(env, 912)

            observations = env.reset()
            
            episode_time_steps = env.time_steps
            done = False
            time_step = 0
            rewards_list = []

            while not done:
                actions = agent.predict(observations)
                
                #print("actions", actions)

                # apply actions to citylearn_env
                next_observations, rewards, done, _ = env.step(actions)
                rewards_list.append(rewards)

                # update
                agent.update(observations, actions, rewards, next_observations, done=done)

                observations = [o for o in next_observations]

                logging.debug(
                    f'Time step: {time_step + 1}/{episode_time_steps},'\
                        f' Episode: {episode + 1}/{episodes},'\
                            f' Actions: {actions},'\
                                f' Rewards: {rewards}'
                )

                time_step += 1

            rewards = np.array(rewards_list, dtype='float')
            rewards_summary = {
                'min': rewards.min(axis=0),
                'max': rewards.max(axis=0),
                'sum': rewards.sum(axis=0),
                'mean': rewards.mean(axis=0)
            }
            #print("episode",episode)
            #print("**len of rewards_summary['sum']",len(rewards_summary['sum']))
            #print("******rewards_summary['sum']",rewards_summary['sum'])
            #print("******rewards_summary['mean']",rewards_summary['mean'])
            #print("******rewards_summary['min']",rewards_summary['min'])
            #print("******rewards_summary['max']",rewards_summary['max'])


            # Step 2: Store Rewards
            #rewards_over_episodes.append(rewards_summary['sum'])
            print(rewards)
            print("len(rewards)",len(rewards))

            episodes_completed += 1

            # Log metrics

            metrics_df = env.evaluate_citylearn_challenge()
            print(f"Episode complete: {episodes_completed} | Latest episode metrics: {metrics_df}", )
            
            logging_metrics = {}
            #print("metrics_df.values()",metrics_df.values())
            

            for metric in metrics_df.values():
                
                logging_metrics[metric['display_name'].replace(" ", "_").lower()] = metric['value']
                
                #print("****",metric['carbon_emissions_total'])

            #wandb.log(logging_metrics)

            logging.info(f'Completed episode: {episode + 1}/{episodes}, Reward: {rewards_summary}')
        # Step 3: Save Rewards
        #df = pd.DataFrame(rewards_over_episodes, columns=['Episode_Reward'])
        #df.to_csv('rewards_over_episodes.csv', index=False)

        # Step 4: Plot Rewards
        #plt.figure(figsize=(10, 5))
        #plt.plot(rewards_over_episodes)
        #plt.xlabel('Episode')
        #plt.ylabel('Reward')
        #plt.title('Reward over Episodes')
        #plt.grid(True)
        #plt.savefig('rewards_over_episodes.png')
        #plt.show()

# %% [markdown]
#  "discount": 0.9,
#       "tau": 0.005,
#       "lr": 0.001,
#       "batch_size": 512,
#       "replay_buffer_capacity": 100000.0,
#       "standardize_start_time_step": 2928,
#       "end_exploration_time_step": 2929,
#       "action_scaling_coef": 0.5,
#       "reward_scaling": 5.0,
#       "update_per_time_step": 2,
#       "alpha": 1.0
#     }

# %%
def evaluate(config, algorithm_config, epochs):

    print("Starting local evaluation")
    
    env, wrapper_env = create_citylearn_env(config, SubmissionReward)
    
    print("Env Created")
    print('Current time step:', env.time_step)
    print('environment number of time steps:', env.time_steps)
    print('environment uses central agent:', env.central_agent)
    print('Common (shared) observations amogst buildings:', env.shared_observations)
    print('Number of buildings:', len(env.buildings))

    agent = SubmissionAgent(wrapper_env, **algorithm_config)

    agent.learn(epochs, deterministic_finish=True)

    observations = env.reset()

    agent_time_elapsed = 0

    step_start = time.perf_counter()
    actions = agent.register_reset(observations)
    agent_time_elapsed += time.perf_counter() - step_start

    episodes_completed = 0
    num_steps = 0
    interrupted = False
    episode_metrics = []

    try:
        while True:
            
            ### This is only a reference script provided to allow you 
            ### to do local evaluation. The evaluator **DOES NOT** 
            ### use this script for orchestrating the evaluations. 

            observations, _, done, _ = env.step(actions)
            if not done:
                step_start = time.perf_counter()
                actions = agent.predict(observations)
                agent_time_elapsed += time.perf_counter()- step_start
            else:
                episodes_completed += 1
                metrics_df = env.evaluate_citylearn_challenge()
                episode_metrics.append(metrics_df)
                print(f"Episode complete: {episodes_completed} | Latest episode metrics: {metrics_df}", )
                
                logging_metrics = {}

                for metric in metrics_df.values():
                    
                    logging_metrics[metric['display_name']] = metric['value']

                #wandb.log(logging_metrics)

                # Optional: Uncomment line below to update power outage random seed 
                # from what was initially defined in schema
                env = update_power_outage_random_seed(env, 90000)

                observations = env.reset()

                step_start = time.perf_counter()
                actions = agent.predict(observations)
                agent_time_elapsed += time.perf_counter()- step_start
            
            num_steps += 1
            if num_steps % 1000 == 0:
                print(f"Num Steps: {num_steps}, Num episodes: {episodes_completed}")

            if episodes_completed >= config.num_episodes:
                break

    except KeyboardInterrupt:
        print("========================= Stopping Evaluation =========================")
        interrupted = True
    
    if not interrupted:
        print("=========================Completed=========================")

    print(f"Total time taken by agent: {agent_time_elapsed}s")

# %%
class Args:
    logs_path = "runs/sac/"
    seed = 1230  # This is just for reproducibility. Different seeds might lead to different results due to the stochastic nature of training.
    epochs = 20
    #learning_rate = 0.0003 #0.001
    learning_rate = 0.0001

    buffer_size = 1000000 #100000
    learning_starts = 100
    batch_size = 32 #512
    #batch_size = 512
    gamma = 0.99 #0.9
    tau = 0.005
    train_freq = 1 #The agent will update its networks every step. This provides fast learning but might become unstable. Consider increasing this if you notice instability.
    qf_nns = 128 #These define the sizes of the layers in your Q-function (critic) and policy (actor) networks. Depending on the complexity of your environment, you might need to adjust these. Complex environments might benefit from larger networks, but this also increases the risk of overfitting.
    pi_nns = 128

#Reward Scaling: SAC is sensitive to reward scaling. If rewards are too large or too small, it can destabilize training.

# %%
#from rewards.MyReward import CombinedRewardFunction
#combined_reward = 0.3*solar_reward + 0.2*marl_reward +0.5*comfort_reward
##no env = update_power_outage_random_seed(env, 90000)
#Central Agent: False
if __name__ == '__main__':

    # Parse command line arguments
    args = Args()


    # Set seed for reproducibility
    set_seed(args.seed)

    algorithm_config = {
        "learning_rate": args.learning_rate,
        "buffer_size": args.buffer_size,
        "learning_starts": args.learning_starts,
        "batch_size": args.batch_size,
        "gamma": args.gamma,
        "tau": args.tau,
        "train_freq": args.train_freq,
        "policy_kwargs": {
            "net_arch": {
                "pi": [args.pi_nns, 2 * args.pi_nns],
                "qf": [args.qf_nns, 2 * args.qf_nns],
            }
        },
    }

     

    class Config:
        data_dir = './data/'
        SCHEMA = os.path.join(data_dir, 'schemas/warm_up/schema.json')
        num_episodes = 1
            
    config = Config()

    train(config, algorithm_config, episodes=args.epochs)

        # evaluate(config, algorithm_config)
# Out:
# Starting local training
# [[ 5.54864837e-03 -9.09015271e-02 -1.98249476e-03]
#  [-2.45363110e-03 -1.16206738e-01 -5.16153478e-04]
#  [ 6.49061281e-03 -1.63513733e-01 -9.56230599e-04]
#  ...
#  [-8.43579797e-01 -4.40381871e-01 -2.65440138e-01]
#  [ 1.73370952e-03 -4.97578119e-01 -9.57946956e-01]
#  [-8.62583200e-01 -1.03883056e+01 -9.17949271e-01]]
# len(rewards) 719
# Episode complete: 1 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.039094153395092}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.7380320889386395}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.588477088279845}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.9762574730049886}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.9739380623617374}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8415503054008413}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7492063492063492}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.5924764237510608}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.8550882}}
# [[ 2.29554885e-02 -9.11025664e-02 -8.87591708e-04]
#  [-8.92952720e-04 -1.19697472e-01 -1.51025682e-03]
#  [-1.29285501e-03 -1.64528541e-01  2.40430581e-02]
#  ...
#  [-4.95226926e+00 -5.58220533e-01  6.61998521e-05]
#  [-4.30553952e+00 -9.21461424e-01  1.60365338e-03]
#  [-2.36403780e+01 -5.29853554e-01 -5.63985417e-03]]
# len(rewards) 719
# Episode complete: 2 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.8143872072431194}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6105357479822652}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.4087050849864793}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.1036657921948856}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.9025224671282691}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 1.0115716011292428}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.573015873015873}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.5700494341786513}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.
__name__ == '__main__':

    # Parse command line arguments
    args = Args()


    # Set seed for reproducibility
    set_seed(args.seed)

    algorithm_config = {
        "learning_rate": args.learning_rate,
        "buffer_size": args.buffer_size,
        "learning_starts": args.learning_starts,
        "batch_size": args.batch_size,
        "gamma": args.gamma,
        "tau": args.tau,
        "train_freq": args.train_freq,
        "policy_kwargs": {
            "net_arch": {
                "pi": [args.pi_nns, 2 * args.pi_nns],
                "qf": [args.qf_nns, 2 * args.qf_nns],
            }
        },
    }

     

    class Config:
        data_dir = './data/'
        SCHEMA = os.path.join(data_dir, 'schemas/warm_up/schema.json')
        num_episodes = 1
            
    config = Config()

    train(config, algorithm_config, episodes=args.epochs)

        # evaluate(config, algorithm_config)
# Out:
# Starting local training
# Env Created
# Current time step: 0
# environment number of time steps: 720
# environment uses central agent: False
# Common (shared) observations amogst buildings: ['month', 'day_type', 'hour', 'daylight_savings_status', 'outdoor_dry_bulb_temperature', 'outdoor_dry_bulb_temperature_predicted_6h', 'outdoor_dry_bulb_temperature_predicted_12h', 'outdoor_dry_bulb_temperature_predicted_24h', 'outdoor_relative_humidity', 'outdoor_relative_humidity_predicted_6h', 'outdoor_relative_humidity_predicted_12h', 'outdoor_relative_humidity_predicted_24h', 'diffuse_solar_irradiance', 'diffuse_solar_irradiance_predicted_6h', 'diffuse_solar_irradiance_predicted_12h', 'diffuse_solar_irradiance_predicted_24h', 'direct_solar_irradiance', 'direct_solar_irradiance_predicted_6h', 'direct_solar_irradiance_predicted_12h', 'direct_solar_irradiance_predicted_24h', 'carbon_intensity', 'electricity_pricing', 'electricity_pricing_predicted_6h', 'electricity_pricing_predicted_12h', 'electricity_pricing_predicted_24h']
# Number of buildings: 3
# episode 0
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-224.72208557 -110.10724384 -230.5094016 ]
# ******rewards_summary['mean'] [-0.3125481  -0.15313942 -0.32059722]
# ******rewards_summary['min'] [-13.78352938 -15.04419969 -17.02747332]
# ******rewards_summary['max'] [0.10141405 0.05055168 0.0194316 ]
# Episode complete: 1 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.018507009107127}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.7330679405594119}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.4183181815022556}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.9833159670720224}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.9907300881190412}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.9391175837856585}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7317460317460318}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.5569063188200686}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.83993006}}
# episode 1
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-106.55138257  -51.45724356 -147.96984768]
# ******rewards_summary['mean'] [-0.14819386 -0.07156779 -0.20579951]
# ******rewards_summary['min'] [-10.51230001  -7.10351964 -21.9890869 ]
# ******rewards_summary['max'] [0.04494477 0.02057492 0.05986855]
# Episode complete: 2 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.8759191681650194}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6920448711721628}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.2779376516161856}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.0007008506908381}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.885013301223045}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.9730359310854789}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.6825396825396824}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6322081207049298}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.80266917}}
# episode 2
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [ -98.81903093  -52.6237414  -135.61352625]
# ******rewards_summary['mean'] [-0.13743954 -0.07319018 -0.18861408]
# ******rewards_summary['min'] [ -9.64451633 -10.46939072 -24.15655706]
# ******rewards_summary['max'] [0.24212059 0.0467799  0.02360294]
# Episode complete: 3 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.8583363450178165}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6753051725338786}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.2622523118688769}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.9913493122117542}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.8708967943177964}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.9835791758253154}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7968253968253968}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.5590971367072259}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.79991937}}
# episode 3
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [ -88.8183849   -41.36228381 -117.69452382]
# ******rewards_summary['mean'] [-0.12353044 -0.05752752 -0.16369197]
# ******rewards_summary['min'] [ -9.63719181  -6.76103842 -13.1404756 ]
# ******rewards_summary['max'] [0.04095246 0.01902196 0.01064887]
# Episode complete: 4 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.8163308479388887}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6862683610044606}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.287896393716932}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.0339471266846911}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.8552582387310804}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8283405689278406}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7301587301587302}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6004305869569319}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.78751016}}
# episode 4
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [ -80.24408526  -44.62545702 -119.76280997]
# ******rewards_summary['mean'] [-0.11160513 -0.062066   -0.16656858]
# ******rewards_summary['min'] [-10.00580554  -6.94190198 -17.18193777]
# ******rewards_summary['max'] [0.06665916 0.0188911  0.02795166]
# Episode complete: 5 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.7889940031877289}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6869815701789433}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.2742676795778098}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.0271331584111436}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.8330561826507269}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.9283900919593544}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7285714285714286}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.5451037400309963}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.78075874}}
# episode 5
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-48.0378528  -32.83634695 -96.755141  ]
# ******rewards_summary['mean'] [-0.06681203 -0.04566947 -0.13456904]
# ******rewards_summary['min'] [ -5.30384588  -4.92702513 -12.47614938]
# ******rewards_summary['max'] [0.02983794 0.01765924 0.0182248 ]
# Episode complete: 42 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.7081340723722698}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6848105210831306}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.1409890046924052}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.0357751954139018}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.7524246619229844}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.759312388793359}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7095238095238096}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6117514980190476}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.7510854}}
# episode 42
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-44.34289714 -33.29354362 -85.10575087]
# ******rewards_summary['mean'] [-0.06167301 -0.04630535 -0.11836683]
# ******rewards_summary['min'] [-4.96156333 -5.66556097 -9.71405766]
# ******rewards_summary['max'] [0.12333545 0.00831802 0.02926867]
# Episode complete: 43 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.7119564510934402}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6879685886562269}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.090443196306096}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.030802450573179}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.7376601224999098}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.6995737411300377}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7730158730158729}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6239472850989071}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.7540167}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 39
#      35     num_episodes = 1
#      37 config = Config()
# ---> 39 train(config, algorithm_config, episodes=args.epochs)
#      41     # evaluate(config, algorithm_config)
#
# Cell In[23], line 51, in train(config, algorithm_config, episodes)
#      48 rewards_list.append(rewards)
#      50 # update
# ---> 51 agent.update(observations, actions, rewards, next_observations, done=done)
#      53 observations = [o for o in next_observations]
#      55 logging.debug(
#      56     f'Time step: {time_step + 1}/{episode_time_steps},'\
#      57         f' Episode: {episode + 1}/{episodes},'\
#      58             f' Actions: {actions},'\
#      59                 f' Rewards: {rewards}'
#      60 )
#
# File ~/work/Neurips_CityLearn/GIT/citylearn-2023-starter-kit/agents/SACmodel.py:129, in SAC_TGELU_WithoutTarget.update(self, observations, actions, reward, next_observations, done)
#     125     new_next_actions, new_log_pi, _ = self.policy_net[i].sample(n)
#     127     # The updated Q-value is found by subtracting the logprob of the sampled action (proportional to the entropy) to the Q-values estimated by the target networks.
#     128     next_q_values = torch.min(
# --> 129         self.soft_q_net1[i](n, new_next_actions),
#     130         self.soft_q_net2[i](n, new_next_actions),
#     131     ) - self.alpha*new_log_pi
#     132     q_target = r + (1 - d)*self.discount*next_q_values
#     134 # Update Soft Q-Networks
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/work/Neurips_CityLearn/GIT/citylearn-2023-starter-kit/agents/rl.py:134, in SoftQNetwork.forward(self, state, action)
#     132 def forward(self, state, action):
#     133     x = torch.cat([state, action], 1)
# --> 134     x = self.ln1(self.act_func(self.linear1(x)))
#     135     x = self.ln2(self.act_func(self.linear2(x)))
#     136     x = self.linear3(x)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/work/Neurips_CityLearn/GIT/citylearn-2023-starter-kit/agents/TGeluu.py:26, in TGeLU.forward(self, input)
#      23 #print(input - self.tr)
#      25 term1 = self.tr*dist.cdf(self.tr) + (input-self.tr)*(1-dist.cdf(input-self.tr))
# ---> 26 term2 = input*dist.cdf(input)
#      27 term3 = input*(1-dist.cdf(input))
#      28 term4 = self.tl*(1-dist.cdf(self.tl)) + (input-self.tl)*dist.cdf(input-self.tl)
#
# File /opt/conda/lib/python3.10/site-packages/torch/distributions/normal.py:86, in Normal.cdf(self, value)
#      84 if self._validate_args:
#      85     self._validate_sample(value)
# ---> 86 return 0.5 * (1 + torch.erf((value - self.loc) * self.scale.reciprocal() / math.sqrt(2)))
#
# KeyboardInterrupt:

# %%
#from rewards.comfort_reward import ComfortRewardFunction

#from rewards.reward_function import MARL
##no env = update_power_outage_random_seed(env, 90000)
#Central Agent: False
if __name__ == '__main__':

    # Parse command line arguments
    args = Args()


    # Set seed for reproducibility
    set_seed(args.seed)

    algorithm_config = {
        "learning_rate": args.learning_rate,
        "buffer_size": args.buffer_size,
        "learning_starts": args.learning_starts,
        "batch_size": args.batch_size,
        "gamma": args.gamma,
        "tau": args.tau,
        "train_freq": args.train_freq,
        "policy_kwargs": {
            "net_arch": {
                "pi": [args.pi_nns, 2 * args.pi_nns],
                "qf": [args.qf_nns, 2 * args.qf_nns],
            }
        },
    }

     

    class Config:
        data_dir = './data/'
        SCHEMA = os.path.join(data_dir, 'schemas/warm_up/schema.json')
        num_episodes = 1
            
    config = Config()

    train(config, algorithm_config, episodes=args.epochs)

        # evaluate(config, algorithm_config)
# Out:
# Starting local training
# Env Created
# Current time step: 0
# environment number of time steps: 720
# environment uses central agent: False
# Common (shared) observations amogst buildings: ['month', 'day_type', 'hour', 'daylight_savings_status', 'outdoor_dry_bulb_temperature', 'outdoor_dry_bulb_temperature_predicted_6h', 'outdoor_dry_bulb_temperature_predicted_12h', 'outdoor_dry_bulb_temperature_predicted_24h', 'outdoor_relative_humidity', 'outdoor_relative_humidity_predicted_6h', 'outdoor_relative_humidity_predicted_12h', 'outdoor_relative_humidity_predicted_24h', 'diffuse_solar_irradiance', 'diffuse_solar_irradiance_predicted_6h', 'diffuse_solar_irradiance_predicted_12h', 'diffuse_solar_irradiance_predicted_24h', 'direct_solar_irradiance', 'direct_solar_irradiance_predicted_6h', 'direct_solar_irradiance_predicted_12h', 'direct_solar_irradiance_predicted_24h', 'carbon_intensity', 'electricity_pricing', 'electricity_pricing_predicted_6h', 'electricity_pricing_predicted_12h', 'electricity_pricing_predicted_24h']
# Number of buildings: 3
# episode 0
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-237.99532561 -107.02031999 -233.41139913]
# ******rewards_summary['mean'] [-0.3310088  -0.14884606 -0.32463338]
# ******rewards_summary['min'] [-17.2179928  -13.6985745  -18.57968703]
# ******rewards_summary['max'] [0.09758226 0.05226731 0.04366805]
# Episode complete: 1 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.0184391896957274}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.7518767855118741}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.4828657633010072}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.9998641775194287}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 1.020879144811114}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.994204472016876}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7047619047619048}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6138904278535057}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.8625408}}
# episode 1
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-104.57608084  -54.309619   -142.72567198]
# ******rewards_summary['mean'] [-0.14544657 -0.07553494 -0.1985058 ]
# ******rewards_summary['min'] [-10.94860456  -7.40993398 -19.67049227]
# ******rewards_summary['max'] [0.02046643 0.01725943 0.0536832 ]
# Episode complete: 2 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.875690748390532}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6920293686440578}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.2602114513284548}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.007696401114205}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.889197998366808}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.9579293840255206}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.6825396825396824}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.636210316141356}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.801618}}
# episode 2
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [ -76.82292106  -58.01061541 -133.06028389]
# ******rewards_summary['mean'] [-0.1068469  -0.08068236 -0.18506298]
# ******rewards_summary['min'] [ -9.71976669 -13.3194649  -20.76745522]
# ******rewards_summary['max'] [0.07545466 0.01991204 0.0178698 ]
# Episode complete: 3 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.8465896580176122}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6984700813049983}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.1761484758901217}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.9975421908360967}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.849470795743495}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.9512522507726064}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7269841269841271}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.5823664404771722}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.78868365}}
# episode 3
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [ -79.99254187  -44.41874461 -115.58095909]
# ******rewards_summary['mean'] [-0.11125527 -0.0617785  -0.16075238]
# ******rewards_summary['min'] [ -8.62086023  -6.79760706 -15.51384154]
# ******rewards_summary['max'] [0.02526991 0.01823547 0.01219464]
# Episode complete: 4 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.819975705157756}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6950706738225941}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.2523674016226174}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.028857651369143}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.8517493457230869}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8463017179721478}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7523809523809524}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6082820004185779}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.7930639}}
# episode 4
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [ -83.10139385  -44.76140635 -123.27185713]
# ******rewards_summary['mean'] [-0.11557913 -0.06225509 -0.17144904]
# ******rewards_summary['min'] [ -8.46364144  -6.99434501 -18.15531358]
# ******rewards_summary['max'] [0.15573773 0.01283522 0.01987312]
# Episode complete: 5 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-54.3827987  -29.54876752 -93.29821475]
# ******rewards_summary['mean'] [-0.07563672 -0.04109703 -0.12976108]
# ******rewards_summary['min'] [ -6.82620373  -5.1289734  -11.22166577]
# ******rewards_summary['max'] [0.04121092 0.01391836 0.01118207]
# Episode complete: 20 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.7018157739691895}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.7044466730622649}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.142218958511937}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.0340415632426305}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.7417592152208768}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.7981828991864081}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.6888888888888888}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.5747962525180127}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.7497835}}

# %%
#from rewards.comfort_reward import MARL

##no env = update_power_outage_random_seed(env, 90000)
#Central Agent : False
if __name__ == '__main__':

    # Parse command line arguments
    args = Args()


    # Set seed for reproducibility
    set_seed(args.seed)

    algorithm_config = {
        "learning_rate": args.learning_rate,
        "buffer_size": args.buffer_size,
        "learning_starts": args.learning_starts,
        "batch_size": args.batch_size,
        "gamma": args.gamma,
        "tau": args.tau,
        "train_freq": args.train_freq,
        "policy_kwargs": {
            "net_arch": {
                "pi": [args.pi_nns, 2 * args.pi_nns],
                "qf": [args.qf_nns, 2 * args.qf_nns],
            }
        },
    }

     

    class Config:
        data_dir = './data/'
        SCHEMA = os.path.join(data_dir, 'schemas/warm_up/schema.json')
        num_episodes = 1
            
    config = Config()

    train(config, algorithm_config, episodes=args.epochs)

        # evaluate(config, algorithm_config)
# Out:
# Starting local training
# Env Created
# Current time step: 0
# environment number of time steps: 720
# environment uses central agent: False
# Common (shared) observations amogst buildings: ['month', 'day_type', 'hour', 'daylight_savings_status', 'outdoor_dry_bulb_temperature', 'outdoor_dry_bulb_temperature_predicted_6h', 'outdoor_dry_bulb_temperature_predicted_12h', 'outdoor_dry_bulb_temperature_predicted_24h', 'outdoor_relative_humidity', 'outdoor_relative_humidity_predicted_6h', 'outdoor_relative_humidity_predicted_12h', 'outdoor_relative_humidity_predicted_24h', 'diffuse_solar_irradiance', 'diffuse_solar_irradiance_predicted_6h', 'diffuse_solar_irradiance_predicted_12h', 'diffuse_solar_irradiance_predicted_24h', 'direct_solar_irradiance', 'direct_solar_irradiance_predicted_6h', 'direct_solar_irradiance_predicted_12h', 'direct_solar_irradiance_predicted_24h', 'carbon_intensity', 'electricity_pricing', 'electricity_pricing_predicted_6h', 'electricity_pricing_predicted_12h', 'electricity_pricing_predicted_24h']
# Number of buildings: 3
# episode 0
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-227.49202787  -97.48264576 -229.88577736]
# ******rewards_summary['mean'] [-0.3164006  -0.13558087 -0.31972987]
# ******rewards_summary['min'] [-13.81745358 -11.67287734 -20.82603533]
# ******rewards_summary['max'] [0.04666426 0.06308477 0.01244551]
# Episode complete: 1 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.015100427609167}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.7289419286268831}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.3735124337225941}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.9986426121509402}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.9891942498753049}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8808426059463107}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7031746031746032}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.5676526875193745}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.8289811}}
# episode 1
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-115.98870548  -48.3445371  -139.36857394]
# ******rewards_summary['mean'] [-0.16131948 -0.06723858 -0.19383668]
# ******rewards_summary['min'] [-17.2977498   -8.01846132 -22.40779577]
# ******rewards_summary['max'] [0.02290873 0.01176767 0.04326021]
# Episode complete: 2 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.8628240966941014}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6749671791075079}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.2773024937717306}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.9957457252904625}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.8810621588160278}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 1.0387160389552883}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.6825396825396824}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6330938833802695}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.80057955}}
# episode 2
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-110.05800223  -52.67267549 -127.55030752]
# ******rewards_summary['mean'] [-0.15307093 -0.07325824 -0.17739959]
# ******rewards_summary['min'] [ -8.42186744 -12.47776059 -18.39672329]
# ******rewards_summary['max'] [0.25325048 0.01997559 0.0137142 ]
# Episode complete: 3 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.8745078881698056}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6673549487279934}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.3049368536260066}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.9811442850240409}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.868114969927398}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.9014311152816297}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7285714285714285}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.5697939795911466}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.78658414}}
# episode 3
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-113.04100576  -47.41977127 -117.48237895]
# ******rewards_summary['mean'] [-0.15721976 -0.06595239 -0.16339691]
# ******rewards_summary['min'] [-10.7282528   -7.76047633 -15.03968724]
# ******rewards_summary['max'] [0.03464491 0.01550474 0.01752187]
# Episode complete: 4 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.8500743043554436}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.6653345638294492}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.3893733356040732}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.0473910798767834}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.9001690746037719}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8493094947932082}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7523809523809524}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6064044841738466}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.80239385}}
# episode 4
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [
, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7936507936507936}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.625023448892474}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.7673055}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 40
#      36     num_episodes = 1
#      38 config = Config()
# ---> 40 train(config, algorithm_config, episodes=args.epochs)
#      42     # evaluate(config, algorithm_config)
#
# Cell In[16], line 51, in train(config, algorithm_config, episodes)
#      48 rewards_list.append(rewards)
#      50 # update
# ---> 51 agent.update(observations, actions, rewards, next_observations, done=done)
#      53 observations = [o for o in next_observations]
#      55 logging.debug(
#      56     f'Time step: {time_step + 1}/{episode_time_steps},'\
#      57         f' Episode: {episode + 1}/{episodes},'\
#      58             f' Actions: {actions},'\
#      59                 f' Rewards: {rewards}'
#      60 )
#
# File ~/work/Neurips_CityLearn/GIT/citylearn-2023-starter-kit/agents/SACmodel.py:153, in SAC_TGELU_WithoutTarget.update(self, observations, actions, reward, next_observations, done)
#     150 self.soft_q_optimizer2[i].step()
#     152 # Update Policy
# --> 153 new_actions, log_pi, _ = self.policy_net[i].sample(o)
#     154 q_new_actions = torch.min(
#     155     self.soft_q_net1[i](o, new_actions),
#     156     self.soft_q_net2[i](o, new_actions)
#     157 )
#     158 policy_loss = (self.alpha*log_pi - q_new_actions).mean()
#
# File ~/work/Neurips_CityLearn/GIT/citylearn-2023-starter-kit/agents/rl.py:60, in PolicyNetwork.sample(self, state)
#      59 def sample(self, state):
# ---> 60     mean, log_std = self.forward(state)
#      61     std = log_std.exp()
#      62     normal = Normal(mean, std)
#
# File ~/work/Neurips_CityLearn/GIT/citylearn-2023-starter-kit/agents/rl.py:53, in PolicyNetwork.forward(self, state)
#      51 def forward(self, state):
#      52     x = self.act_func(self.linear1(state))
# ---> 53     x = self.act_func(self.linear2(x))
#      54     mean = self.mean_linear(x)
#      55     log_std = self.log_std_linear(x)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/work/Neurips_CityLearn/GIT/citylearn-2023-starter-kit/agents/TGeluu.py:27, in TGeLU.forward(self, input)
#      25 term1 = self.tr*dist.cdf(self.tr) + (input-self.tr)*(1-dist.cdf(input-self.tr))
#      26 term2 = input*dist.cdf(input)
# ---> 27 term3 = input*(1-dist.cdf(input))
#      28 term4 = self.tl*(1-dist.cdf(self.tl)) + (input-self.tl)*dist.cdf(input-self.tl)
#      30 return cond1*term1 + cond2*term2 + cond3*term3 + cond4*term4
#
# KeyboardInterrupt:

# %%
#from citylearn.agents.sac import SAC
#from rewards.reward_function import IndependentSACReward
##env = update_power_outage_random_seed(env, 90000)
if __name__ == '__main__':

    # Parse command line arguments
    args = Args()


    # Set seed for reproducibility
    set_seed(args.seed)

    algorithm_config = {
        "learning_rate": args.learning_rate,
        "buffer_size": args.buffer_size,
        "learning_starts": args.learning_starts,
        "batch_size": args.batch_size,
        "gamma": args.gamma,
        "tau": args.tau,
        "train_freq": args.train_freq,
        "policy_kwargs": {
            "net_arch": {
                "pi": [args.pi_nns, 2 * args.pi_nns],
                "qf": [args.qf_nns, 2 * args.qf_nns],
            }
        },
    }

     

    class Config:
        data_dir = './data/'
        SCHEMA = os.path.join(data_dir, 'schemas/warm_up/schema.json')
        num_episodes = 1
            
    config = Config()

    train(config, algorithm_config, episodes=args.epochs)

        # evaluate(config, algorithm_config)
# Out:
# Starting local training
# episode 0
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-1237.44815768  -827.96374493 -1150.99735965]
# ******rewards_summary['mean'] [-1.72106837 -1.15154902 -1.60083082]
# ******rewards_summary['min'] [ -9.68089771 -10.07601929 -10.39554691]
# ******rewards_summary['max'] [0. 0. 0.]
# Episode complete: 1 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.0203829590768152}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.7354631304950163}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.4268334702890737}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.9758296839543006}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.9778971585231017}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.9470135474076838}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': nan}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': nan}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.6472453}}
# episode 1
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-558.49986514 -337.6025879  -567.20284644]
# ******rewards_summary['mean'] [-0.77677311 -0.46954463 -0.78887739]
# ******rewards_summary['min'] [-7.71980858 -8.63958645 -9.09844208]
# ******rewards_summary['max'] [0. 0. 0.]
# Episode complete: 2 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.544061413069161}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.913025158806435}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 0.9941520669901034}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.1887632191836333}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.7344523570430279}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8510289378117679}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': nan}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': nan}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.61094344}}
# episode 2
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-448.18440713 -262.18779789 -516.87833574]
# ******rewards_summary['mean'] [-0.6233441  -0.36465619 -0.71888503]
# ******rewards_summary['min'] [-7.47926903 -8.33166027 -8.99903393]
# ******rewards_summary['max'] [0. 0. 0.]
# Episode complete: 13 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.4590973757765957}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.9765634689987114}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 0.9916898211398186}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.2267888684249806}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.6808414403559241}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8368964260528647}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': nan}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': nan}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.619095}}
# episode 13
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-446.36418182 -265.61834237 -517.79892267]
# ******rewards_summary['mean'] [-0.62081249 -0.36942746 -0.7201654 ]
# ******rewards_summary['min'] [-7.67018557 -8.08549118 -8.71222782]
# ******rewards_summary['max'] [0. 0. 0.]
# Episode complete: 14 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.461058079139123}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.9781601031325348}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 0.9611117927901516}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.2282229072433286}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.6880271487715242}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.819375006089688}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': nan}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': nan}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.61680907}}
# episode 14
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-440.2898825  -272.61071383 -513.54959771]
# ******rewards_summary['mean'] [-0.61236423 -0.37915259 -0.71425535]
# ******rewards_summary['min'] [-7.44734573 -8.60348511 -9.17392063]
# ******rewards_summary['max'] [0. 0. 0.]
# Episode complete: 15 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.4606274507910082}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.9743846715413976}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 0.958780878648548}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.2541517418716697}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.7256029460343498}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8393307163913855}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': nan}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': nan}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.62171805}}
# episode 15
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-459.55668585 -282.86035606 -520.97875561]
# ******rewards_summary['mean'] [-0.6391609  -0.39340801 -0.72458798]
# ******rewards_summary['min'] [-8.09503555 -8.6112175  -9.34347439]
# ******rewards_summary['max'] [0. 0. 0.]
# Episode complete: 16 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.4754974373189476}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.9767377149764686}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 0.9711403614874599}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.221317154940204}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.6972903606854952}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8510378515679076}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': nan}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': nan}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.62113}}
# episode 16
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-470.76424956 -284.43255085 -508.38825315]
# ******rewards_summary['mean'] [-0.65474861 -0.39559465 -0.70707685]
# ******rewards_summary['min'] [-8.16226292 -8.61450768 -8.7727499 ]
# ******rewards_summary['max'] [0. 0. 0.]
# Episode complete: 17 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.4746724789919375}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.962917243098902}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 0.9701295432984102}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.2203435790450188}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.697253539299384}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.7939729323038988}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': nan}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': nan}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.61246985}}
# episode 17
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-469.40413016 -273.28834441 -513.27377756]
# ******rewards_summary['mean'] [-0.65285693 -0.38009505 -0.71387174]
# ******rewards_summary['min'] [-7.34703445 -8.58137798 -8.59873867]
# ******rewards_summary['max'] [0. 0. 0.]
# Episode complete: 18 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.46959820818073145}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.9737981471341256}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 0.9887078048073797}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.233485112533139}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.6992771770544721}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8097993198168144}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': nan}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': nan}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.6189445}}
# episode 18
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-471.07784406 -268.61822631 -520.90714318]
# ******rewards_summary['mean'] [-0.65518476 -0.37359976 -0.72448838]
# ******rewards_summary['min'] [-7.49663973 -8.62809086 -9.08319283]
# ******rewards_summary['max'] [0. 0. 0.]
# Episode complete: 19 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.470187767428563}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.9681009259685288}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.0108592550200435}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.225935267821755}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.702968572236823}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8603440366856314}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': nan}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': nan}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.622457}}
# episode 19
# **len of rewards_summary['sum'] 3
# ******rewards_summary['sum'] [-456.00240275 -264.12659214 -514.22531588]
# ******rewards_summary['mean'] [-0.63421753 -0.3673527  -0.71519515]
# ******rewards_summary['min'] [-7.79920053 -8.608284   -9.05112171]
# ******rewards_summary['max'] [0. 0. 0.]
# Episode complete: 20 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0.4612203456162494}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.972462881966938}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 0.972471622854227}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 1.2422524422207362}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.7021647247674105}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8434085539038446}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': nan}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': nan}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.61988324}}

# %%
#from citylearn.agents.sac import SAC
#from rewards.reward_function import IndependentSACReward
if __name__ == '__main__':

    # Parse command line arguments
    args = Args()


    # Set seed for reproducibility
    set_seed(args.seed)

    algorithm_config = {
        "learning_rate": args.learning_rate,
        "buffer_size": args.buffer_size,
        "learning_starts": args.learning_starts,
        "batch_size": args.batch_size,
        "gamma": args.gamma,
        "tau": args.tau,
        "train_freq": args.train_freq,
        "policy_kwargs": {
            "net_arch": {
                "pi": [args.pi_nns, 2 * args.pi_nns],
                "qf": [args.qf_nns, 2 * args.qf_nns],
            }
        },
    }

     

    class Config:
        data_dir = './data/'
        SCHEMA = os.path.join(data_dir, 'schemas/warm_up/schema.json')
        num_episodes = 1
            
    config = Config()

    evaluate(config, algorithm_config, episodes=1)

        # evaluate(config, algorithm_config)

# %%
#from citylearn.agents.sac import SAC
#from rewards.reward_function import IndependentSACReward
if __name__ == '__main__':

    # Parse command line arguments
    args = Args()


    # Set seed for reproducibility
    set_seed(args.seed)

    algorithm_config = {
        "learning_rate": args.learning_rate,
        "buffer_size": args.buffer_size,
        "learning_starts": args.learning_starts,
        "batch_size": args.batch_size,
        "gamma": args.gamma,
        "tau": args.tau,
        "train_freq": args.train_freq,
        "policy_kwargs": {
            "net_arch": {
                "pi": [args.pi_nns, 2 * args.pi_nns],
                "qf": [args.qf_nns, 2 * args.qf_nns],
            }
        },
    }

     

    class Config:
        data_dir = './data/'
        SCHEMA = os.path.join(data_dir, 'schemas/warm_up/schema.json')
        num_episodes = 1
            
    config = Config()

    train(config, algorithm_config, episodes=args.epochs)

        # evaluate(config, algorithm_config)
# Out:
# Starting local training
# Episode complete: 1 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.0236195278204594}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.7508823437588691}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.3972392294912823}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.9759179532509699}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.9902459888401706}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8720518834096669}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.6349206349206349}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.635805206867794}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.8358947}}
# Episode complete: 2 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 0
, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.9408426}}
# Episode complete: 4 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.3371209040583611}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.9372233483735429}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.0364470327407675}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.77533330022666}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 1.092742170644485}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 1.0635301461517095}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.8634920634920635}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.7009953710288056}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.94715613}}
# Episode complete: 5 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.3484038660028546}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.9373777307394136}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.0503752298185314}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.7829736318714593}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 1.1044078008104243}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 1.0551563616880812}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.8873015873015874}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6930295300012649}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.95257187}}
# Episode complete: 6 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.3955371753687171}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.9321137052414498}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.1796197361322576}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.8000402314716673}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 1.1410613161968395}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 1.1226199436858633}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.8174603174603176}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6890719294217421}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.96341825}}
# Episode complete: 7 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.4138295819456592}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.9286513994658353}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.1169498665793802}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.8115645123302414}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 1.1681511212918163}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 1.0970717571667459}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7730158730158729}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6921130738949057}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.95427805}}
# Episode complete: 8 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.3976062312566382}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.926738332058939}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.11339196710625}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.7800134682841917}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 1.1267891798665917}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 1.099787255178968}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7952380952380952}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6837418269684199}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.9486277}}
# Episode complete: 9 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.3942463238703031}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.9275146049720732}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.0976765370639756}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.7946647564302759}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 1.142325928198375}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 1.085719266586061}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.8412698412698413}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.7116364178900557}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.95964396}}
# Episode complete: 10 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.3901194649456308}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.934335537380087}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.0880793483641666}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.7966618127317872}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 1.1366081923899118}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 1.0753684729523931}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.8650793650793651}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6549693287423076}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.95457375}}

# %%
#class BasicRBCAgent(SAC):

if __name__ == '__main__':

    # Parse command line arguments
    args = Args()


    # Set seed for reproducibility
    set_seed(args.seed)

    algorithm_config = {
        "learning_rate": args.learning_rate,
        "buffer_size": args.buffer_size,
        "learning_starts": args.learning_starts,
        "batch_size": args.batch_size,
        "gamma": args.gamma,
        "tau": args.tau,
        "train_freq": args.train_freq,
        "policy_kwargs": {
            "net_arch": {
                "pi": [args.pi_nns, 2 * args.pi_nns],
                "qf": [args.qf_nns, 2 * args.qf_nns],
            }
        },
    }

     

    class Config:
        data_dir = './data/'
        SCHEMA = os.path.join(data_dir, 'schemas/warm_up/schema.json')
        num_episodes = 1
            
    config = Config()

    train(config, algorithm_config, episodes=args.epochs)

        # evaluate(config, algorithm_config)
# Out:
# Starting local training
# Episode complete: 1 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.0216359997145952}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.7446115159919041}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.3589104328711592}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.9786696747133896}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 0.9690514842486116}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.8757955129911316}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.7507936507936508}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6137836818238166}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.8439157}}
# Episode complete: 2 | Latest episode metrics: {'carbon_emissions_total': {'display_name': 'Carbon emissions', 'weight': 0.1, 'value': 1.2786631787307916}, 'discomfort_proportion': {'display_name': 'Unmet hours', 'weight': 0.3, 'value': 0.897790690049483}, 'ramping_average': {'display_name': 'Ramping', 'weight': 0.075, 'value': 1.1102812523981618}, 'daily_one_minus_load_factor_average': {'display_name': 'Load factor', 'weight': 0.075, 'value': 0.8211706785188817}, 'daily_peak_average': {'display_name': 'Daily peak', 'weight': 0.075, 'value': 1.08263963754674}, 'annual_peak_average': {'display_name': 'All-time peak', 'weight': 0.075, 'value': 0.9627071367218221}, 'one_minus_thermal_resilience_proportion': {'display_name': 'Thermal resilience', 'weight': 0.15, 'value': 0.8603174603174604}, 'power_outage_normalized_unserved_energy_total': {'display_name': 'Unserved energy', 'weight': 0.15, 'value': 0.6845905513057814}, 'average_score': {'display_name': 'Score', 'weight': None, 'value': 0.9271996}}
